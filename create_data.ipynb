# %%
import pandas as pd

from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("data/creditcard.csv")
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
non_fraud = data[data['Class'] == 0]
fraud = data[data['Class'] == 1]
non_fraud.shape, fraud.shape
# Out:
# ((284315, 31), (492, 31))

# %%
non_fraud_train, non_fraud_test = train_test_split(non_fraud, test_size=0.25, random_state=7)
fraud_train, fraud_test = train_test_split(fraud, test_size=0.25, random_state=7)
non_fraud_train.shape, non_fraud_test.shape, fraud_train.shape, fraud_test.shape
# Out:
# ((213236, 31), (71079, 31), (369, 31), (123, 31))

# %%
train = pd.concat([non_fraud_train, fraud_train])
test = pd.concat([non_fraud_test, fraud_test])
train.shape, test.shape
# Out:
# ((213605, 31), (71202, 31))

# %%
train.to_csv('data/creditcard_train.csv', header=False, index=False)
test.to_csv('data/creditcard_test.csv', header=False, index=False)

# %%
# %%bash
# head -2 data/creditcard_train.csv
# head -2 data/creditcard_test.csv
# Out:
# 49610.0,-0.9444073103843791,0.368281318799856,1.4376377751648601,-0.458454030364063,0.739651574240693,-0.912192260538569,0.311412808972918,0.204728188264533,-0.439339707555063,-0.71884276727651,0.730138613127412,-0.556274190580421,-2.00069970021585,0.185947104358899,0.0178574753440908,1.00838613885305,-0.493035281809098,0.668219934431783,-0.302436777472342,-0.0782302273699214,-0.156155221016965,-0.820937996198045,-0.0287641311090299,-0.10672359557342301,-0.184500626448884,-0.0476088593330777,0.0074855755124740705,0.107182358880921,1.29,0
# ...
